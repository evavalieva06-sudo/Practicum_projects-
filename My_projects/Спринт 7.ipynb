# %% [markdown]
# Привет, Ева!
#
# Меня зовут Вячеслав Погорелый, и я буду проводить ревью твоего проекта.
#
# Предлагаю перейти на "ты", если не против)
#
# Но если это не удобно - дай знать, и мы перейдем на "вы". Моя главная задача — не находить сделанные тобою ошибки, а передать свой опыт и помочь тебе стать аналитиком данных.
#
# Я отметил комментарии и замечания разным цветом далее по тексту markdown:
#
# ---
# <div class="alert alert-block alert-danger">
#
# ### Ошибка
#
# Критическое замечание, которые следует исправить.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">
#
# ### Совет
#
# Замечание\совет на будущее.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">
#
# ### Успех
#
# Все здорово

# %% [markdown]
# # Предобработка данных по развитию индустрии игр в начале XXI века
#
# - Автор: Валиева Ева
# - Дата: 10.05.2026

# %% [markdown]
# ### Цели и задачи проекта
#
# **Цель** – преобразовать данные для дальнейшего анализа развития индустрии игр в начале XXI века.
# **Задачи**:
# 1.  Познакомиться с данными, первичный анализ
# 2.	Привести названия к snake case
# 3.	Проанализировать и при необходимости преобразовать типы данных
# 4.	Посчитать пропуски, установить их причины, обработать их
# 5.	Провести фильтрацию данных
# 6.	Категоризировать значения

# %% [markdown]
# ### Описание данных
#
# **Данные `/datasets/new_games.csv` содержат информацию о продажах игр разных жанров и платформ, а также пользовательские и экспертные оценки игр:**
#
# `Name` — название игры.
#
# `Platform` — название платформы.
#
# `Year of Release` — год выпуска игры.
#
# `Genre` — жанр игры.
#
# `NA sales` — продажи в Северной Америке (в миллионах проданных копий).
#
# `EU sales` — продажи в Европе (в миллионах проданных копий).
#
# `JP sales` — продажи в Японии (в миллионах проданных копий).
#
# `Other sales` — продажи в других странах (в миллионах проданных копий).
#
# `Critic Score` — оценка критиков (от 0 до 100).
#
# `User Score` — оценка пользователей (от 0 до 10).
#
# `Rating` — рейтинг организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
# </font>

# %% [markdown]
# ### Содержимое проекта
#
#
# 1.	Загрузка данных и знакомство с ними.
# 2.	Проверка ошибок в данных и их предобработка
# 3.	Фильтрация данных
# 4.	Категоризация данных
# 5.	Итоговый вывод
#
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Хорошо, что есть заголовок с описанием и планом проекта. Так проект выглядит более опрятно.

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними
#
# - Загрузите необходимые библиотеки Python и данные датасета `/datasets/new_games.csv`.

# %%
# Пустые ячейки после каждого задания — примерное пространство для работы.
# Вы можете свободно добавлять или удалять ячейки по своему усмотрению в зависимости от логики и объёма работы.

# %%
# Используйте ячейки типа Code для вашего кода

# %%
# При необходимости добавьте новые ячейки для кода

# %% [markdown]
# - Познакомьтесь с данными: выведите первые строки и результат метода `info()`.

# %%
import pandas as pd

# %%
df = pd.read_csv('/datasets/new_games.csv')

# %%
print(df.head())
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        sports     41.36
# 1         Super Mario Bros.      NES             1985      platform     29.08
# 2            Mario Kart Wii      Wii             2008        racing     15.68
# 3         Wii Sports Resort      Wii             2009        sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45            76         8.0      E
# 1      3.58      6.81         0.77             0         NaN    NaN
# 2     12.76      3.79         3.29            82         8.3      E
# 3     10.93      3.28         2.95            80         8.0      E
# 4      8.89     10.22         1.00             0         NaN    NaN

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16956 entries, 0 to 16955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16954 non-null  object
#  1   Platform         16956 non-null  object
#  2   Year of Release  16681 non-null  float64
#  3   Genre            16954 non-null  object
#  4   NA sales         16956 non-null  float64
#  5   EU sales         16956 non-null  object
#  6   JP sales         16956 non-null  object
#  7   Other sales      16956 non-null  float64
#  8   Critic Score     8242 non-null   float64
#  9   User Score       10152 non-null  object
#  10  Rating           10085 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# - Сделайте вывод о полученных данных: данные какого объёма вам предоставили, соответствуют ли они описанию, встречаются ли в них пропуски, используются ли верные типы данных.
# - Отметьте другие особенности данных, которые вы обнаружили и на которые стоит обратить внимание при предобработке. Например, вы можете проверить названия столбцов: все ли названия отражают содержимое данных и прописаны в удобном для работы виде.

# %% [markdown]
# <font color='#777778'>Используйте ячейки типа Markdown для промежуточных выводов и расширенных комментариев к действиям с данными. </font>

# %% [markdown]
# Были предоставлены данные около 1.5 МБ. Они содержат в себе 16956 строк, 11 столбцов, 4 из которых представлены вещественным типом данных, 7 - объектами. В некоторых столбцах используются неверные типы данных (`EU sales`, `JP sales`, `User Score`, `Rating`). `Year of release` можно привести к целочисленному типу. Необходимо удостовериться, что содержится в строках этих столбцов и при необходимости изменить типы данных.

# %% [markdown]
# Пропуски содержатся в 6/11 столбцов. В столбце `Name` есть два пропуска, которые бросаются в глаза, стоит изучить почему они возникают. Есть и столбцы, где намного больше пропусков, что тоже важно учесть при предобработке данных (например, `Critic Score`, `User Score`, `Rating`).

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Отличное начало получилось. Мы с данными ознакомились и получили первую информацию о данных. У нас содержутся в датасете пропуски, а также кривое написание в данных. К тому же есть проблемы связанные с типом данных.

# %% [markdown]
# ---
#
# ## 2.  Проверка ошибок в данных и их предобработка
#
#
# ### 2.1. Названия, или метки, столбцов датафрейма
#
# - Выведите на экран названия всех столбцов датафрейма и проверьте их стиль написания.
# - Приведите все столбцы к стилю snake case. Названия должны быть в нижнем регистре, а вместо пробелов — подчёркивания.

# %%
print(df.columns)
# Out:
# Index(['Name', 'Platform', 'Year of Release', 'Genre', 'NA sales', 'EU sales',
#        'JP sales', 'Other sales', 'Critic Score', 'User Score', 'Rating'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Когда у тебя код это единственная строчка в ячейке, то вывод сработает и без команды print()

# %%
df = df.rename(columns={
    'Name': 'name',
    'Platform': 'platform',
    'Year of Release': 'year_of_release',
    'Genre': 'genre',
    'NA sales': 'na_sales', 
    'EU sales': 'eu_sales',
    'JP sales': 'jp_sales', 
    'Other sales': 'other_sales', 
    'Critic Score': 'critic_score', 
    'User Score': 'user_score',
    'Rating': 'rating'
}
                       )

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16956 entries, 0 to 16955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16954 non-null  object
#  1   platform         16956 non-null  object
#  2   year_of_release  16681 non-null  float64
#  3   genre            16954 non-null  object
#  4   na_sales         16956 non-null  float64
#  5   eu_sales         16956 non-null  object
#  6   jp_sales         16956 non-null  object
#  7   other_sales      16956 non-null  float64
#  8   critic_score     8242 non-null   float64
#  9   user_score       10152 non-null  object
#  10  rating           10085 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Для приведения к нижнему регистру можно использовать df.columns = df.columns.str.lower()

# %% [markdown]
# Были переименованы все столбцы с учетом snake case - уменьшен регистр и добавлены нижние подчеркивания.

# %% [markdown]
# ### 2.2. Типы данных
#
# - Если встречаются некорректные типы данных, предположите их причины.
# - При необходимости проведите преобразование типов данных. Помните, что столбцы с числовыми данными и пропусками нельзя преобразовать к типу `int64`. Сначала вам понадобится обработать пропуски, а затем преобразовать типы данных.

# %%
df['eu_sales'] = pd.to_numeric(df['eu_sales'], errors='coerce')

# %%
df['jp_sales'] = pd.to_numeric(df['jp_sales'], errors='coerce')

# %% [markdown]
# Переводим столбцы без пропусков из типа объекта в вещественный тип, заменяя значения на Nan, чтобы иметь возможность проводить с ними операции.

# %% [markdown]
# - В числовых столбцах могут встретиться строковые значения, например `unknown` или другие. Приводите такие столбцы к числовому типу данных, заменив строковые значения на пропуски.

# %%
unique_user_score = df['user_score'].unique()
print(unique_user_score)
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')
# Out:
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
#  '1.8' '3.8' '0' '1.6' '9.6' '2.4' '1.7' '1.1' '0.3' '1.5' '0.7' '1.2'
#  '2.3' '0.5' '1.3' '0.2' '0.6' '1.4' '0.9' '1' '9.7']

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Здесь отлично получилось

# %% [markdown]
# Проанализировав, какие значения хранит в себе `user_score`, расшифруем непонятные: tbd - "подлежит уточнению". Это не несет практического смысла для анализа, поэтому можно заменить на Nan, чтобы иметь возможность проводить операции. Приводим `user_score` к вещественному типу для этого.

# %%
unique_year_of_release = df['year_of_release'].unique()
print(unique_year_of_release)
df['year_of_release'] = df['year_of_release'].fillna(0).astype('int64')
# Out:
# [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2016. 2003. 1986. 2000.   nan 1995. 1991. 1981. 1987.
#  1980. 1983.]

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Для экономии вычислительной памяти лучше всего перевести в int32

# %%
unique_critic_score = df['critic_score'].unique()
print(unique_critic_score)
df['critic_score'] = df['critic_score'].fillna(0).astype('int64')
# Out:
# [76. nan 82. 80. 89. 58. 87. 91. 61. 97. 95. 77. 88. 83. 94. 93. 85. 86.
#  98. 96. 90. 84. 73. 74. 78. 92. 71. 72. 68. 62. 49. 67. 81. 66. 56. 79.
#  70. 59. 64. 75. 60. 63. 69. 50. 25. 42. 44. 55. 48. 57. 29. 47. 65. 54.
#  20. 53. 37. 38. 33. 52. 30. 32. 43. 45. 51. 40. 46. 39. 34. 35. 41. 36.
#  28. 31. 27. 26. 19. 23. 24. 21. 17. 22. 13.]

# %% [markdown]
# Теперь переходим к двум столбцам, в которых нужно установить целочисленный тип. Это нельзя сделать без заполения пропусков, поэтому изучив содержимое столбцов, заменяем пропуски на 0, что соответствует смыслу и не принесет вреда анализу, потому что игры без известного года придется отбросить, так как нас интересует только с 2000 по 2013 год включительно. А потеря рейтинга критиков будет компенсирована рейтингом пользователей при наличии.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16956 entries, 0 to 16955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16954 non-null  object
#  1   platform         16956 non-null  object
#  2   year_of_release  16956 non-null  int64
#  3   genre            16954 non-null  object
#  4   na_sales         16956 non-null  float64
#  5   eu_sales         16950 non-null  float64
#  6   jp_sales         16952 non-null  float64
#  7   other_sales      16956 non-null  float64
#  8   critic_score     16956 non-null  int64
#  9   user_score       7688 non-null   float64
#  10  rating           10085 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# Теперь датафрейм содержит 5 вещественных столбцов, 2 целочисленных и 4 столбца типа объект.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# По типу данных нареканий нет!

# %% [markdown]
# ### 2.3. Наличие пропусков в данных
#
# - Посчитайте количество пропусков в каждом столбце в абсолютных и относительных значениях.

# %%
abs_missing = df.isna().sum()
print(f' Абсолютное значение пропусков: {abs_missing}')
# Out:
#  Абсолютное значение пропусков: name                         0
# platform                     0
# year_of_release              0
# genre                        0
# na_sales                     0
# eu_sales                     0
# jp_sales                     0
# other_sales                  0
# critic_score                 0
# user_score                9123
# rating                    6764
# category_user_score      10230
# category_critic_score     3932
# dtype: int64

# %%
real_missing = (df.isna().sum() / len(df)) * 100
print(f' Относительное значение пропусков: {real_missing}')
# Out:
#  Относительное значение пропусков: name                      0.000000
# platform                  0.000000
# year_of_release           0.000000
# genre                     0.000000
# na_sales                  0.000000
# eu_sales                  0.000000
# jp_sales                  0.000000
# other_sales               0.000000
# critic_score              0.000000
# user_score               54.586250
# rating                   40.471489
# category_user_score      61.209837
# category_critic_score    23.526596
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарии от ревьюера:
#
# #### Совет
#
# Возможно пригодится еще на будущее библиотека по визуализации пропущенных значений https://pythontalk.olegtalks.ru/missingno_library

# %% [markdown]
# - Изучите данные с пропущенными значениями. Напишите промежуточный вывод: для каких столбцов характерны пропуски и сколько их. Предположите, почему пропуски могли возникнуть. Укажите, какие действия с этими данными можно сделать и почему.

# %% [markdown]
# Столбцы `eu_sales` и `jp_sales` важно обработать и заменить значения 0 на среднее по группе для более адекватного и отображения данных.

# %%
def mean_sales_eu(row):
    if pd.isna(row['eu_sales']):
        sales = df[(df['platform'] == row['platform']) &
                          (df['year_of_release'] == row['year_of_release'])]
        return sales['eu_sales'].mean()
    else:
        return row['eu_sales']

    df['eu_sales'] = df.apply(mean_sales_eu, axis=1)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Достаточно точечный метод проработки получился у тебя. Отлично

# %% [markdown]
# Я нашла пропущенные значения в поле `name` и определила, что две игры с пропущенными названиями также имеют пропущенным жанр, приэтом они не входят в фильтр, который мы дальше будем использовать, что означает, что эти две строки можно будет удалить без потерь.

# %%
df = df.dropna(subset=['name'])

# %% [markdown]
# Два столбца содержат очень высокий процент пропусков – `user_score` (54.65) и `rating` (40.52). Это может означать недостаточное количество данных, полученное при создании базы игр. Пользователи могли еще не успеть или вовсе просто не оставить оценки игре, потому что она непопулярна. Игра могла не получить рейтинг по той же последней причине или быть в поле неопределенного рейтинга. Это все равно важно для дальнейшей категоризации, поэтому пропуски пропустим.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Причины возможного появления пропусков вполне жизнеспособные. Отлично

# %% [markdown]
# - Обработайте пропущенные значения. Для каждого случая вы можете выбрать оптимальный, на ваш взгляд, вариант: заменить на определённое значение, оставить как есть или удалить.
# - Если вы решите заменить пропуски на значение-индикатор, то убедитесь, что предложенное значение не может быть использовано в данных.
# - Если вы нашли пропуски в данных с количеством проданных копий игры в том или ином регионе, их можно заменить на среднее значение в зависимости от названия платформы и года выхода игры.

# %% [markdown]
# ### 2.4. Явные и неявные дубликаты в данных
#
# - Изучите уникальные значения в категориальных данных, например с названиями жанра игры, платформы, рейтинга и года выпуска. Проверьте, встречаются ли среди данных неявные дубликаты, связанные с опечатками или разным способом написания.
# - При необходимости проведите нормализацию данных с текстовыми значениями. Названия или жанры игр можно привести к нижнему регистру, а названия рейтинга — к верхнему.

# %%
unique_year_of_release = df['year_of_release'].unique()
print(unique_year_of_release)
# Нет опечаток и аномальных значений
# Out:
# [2006 1985 2008 2009 1996 1989 1984 2005 1999 2007 2010 2013 2004 1990
#  1988 2002 2001 2011 1998 2015 2012 2014 1992 1997 1993 1994 1982 2016
#  2003 1986 2000    0 1995 1991 1981 1987 1980 1983]

# %%
unique_genre = df['genre'].unique()
print(unique_genre) 
# Есть дубликаты, написанные в разном регистре, необходимо привести к единому и убрать дублирование
# Out:
# ['sports' 'platform' 'racing' 'role-playing' 'puzzle' 'misc' 'shooter'
#  'simulation' 'action' 'fighting' 'adventure' 'strategy']

# %%
df['genre'] = df['genre'].str.lower()
# Приводим жанры к единому нижнему регистру

# %%
unique_platform = df['platform'].unique()
print(unique_platform)
# Дубликатов нет
# Out:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']

# %%
unique_rating = df['rating'].unique()
print(unique_rating)
# Дубликаты также отсутствуют
# Out:
# ['E' nan 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']

# %% [markdown]
# - После того как нормализуете данные и устраните неявные дубликаты, проверьте наличие явных дубликатов в данных.

# %%
print(f"Всего строк: {len(df)}")
print(f"Количество дубликатов: {df.duplicated().sum()}")
# Получился целый 241 явный дубликат
# Out:
# Всего строк: 16713
# Количество дубликатов: 0

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Дубликаты проработаны в данном случе. Здорово

# %%
df = df.drop_duplicates()

# %% [markdown]
# Удалили явные дубликаты

# %% [markdown]
# - Напишите промежуточный вывод: укажите количество найденных дубликатов и действия по их обработке.

# %% [markdown]
# Были найдены и устранены дубликаты в столбцах жанров и в общем по всем столбцам. Столбцы жанров были приведены к одному формату (нижний регистр) и дубликаты были устранены. Остальные столбцы не были отмечены неявными дубликатами.
# Явные дубликаты были удалены в количестве 241

# %% [markdown]
# - В процессе подготовки данных вы могли что-либо удалять, например строки с пропусками или ошибками, дубликаты и прочее. В этом случае посчитайте количество удалённых строк в абсолютном и относительном значениях.

# %% [markdown]
# Изначально в датафрейме было 16956 строк. Теперь осталось 16713. Был удален 241 явный дубликат и 2 строки с пропущенными названиями и жанрами, итого 243 удаленных строки.

# %%
print(f'Абсолютное значение: {16956 - 16713}')
# Out:
# Абсолютное значение: 243

# %%
print(f'Относительное значение: {round(243 / 16956 * 100, 2)}%')
# Out:
# Относительное значение: 1.43%

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Данных у нас осталось достаточно для того, чтобы сделать корректные выводы.

# %% [markdown]
# - После проведения предобработки данных напишите общий промежуточный вывод.

# %% [markdown]
# Подводя промежуточный итог, данные были избавлены от ошибок, дубликатов и лишних пропусков. Где-то их количество достигало очень большого значения, что влияет на качество предоставленных данных, но так как процент слишком велик, то лучшим решением будет не трогать их. Количество неявных дубликатов было незначительным и быстро было исправлено. Явные дубликаты устранены, данные готовы к дальнейшей работе.

# %% [markdown]
# ---
#
# ## 3. Фильтрация данных
#
# Коллеги хотят изучить историю продаж игр в начале XXI века, и их интересует период с 2000 по 2013 год включительно. Отберите данные по этому показателю. Сохраните новый срез данных в отдельном датафрейме, например `df_actual`.

# %%
df_actual = df.loc[(df['year_of_release'] >= 2000) & (df['year_of_release'] <= 2013)]

# %%
print(df_actual.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12781 entries, 0 to 16954
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 12781 non-null  object
#  1   platform             12781 non-null  object
#  2   year_of_release      12781 non-null  int64
#  3   genre                12781 non-null  object
#  4   na_sales             12781 non-null  float64
#  5   eu_sales             12781 non-null  float64
#  6   jp_sales             12781 non-null  float64
#  7   other_sales          12781 non-null  float64
#  8   critic_score         12781 non-null  int64
#  9   user_score           6483 non-null   float64
#  10  rating               8723 non-null   object
#  11  category_user_score  6482 non-null   category
# dtypes: category(1), float64(5), int64(2), object(4)
# memory usage: 1.2+ MB
# None

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Хороший метод фильтрации вышел. Отдельно хочу порекомендовать альтернативу https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html

# %% [markdown]
# В новом датафрейме остается 12781 строка, которые содержат в себе отфильтрованные данные по фильмам с 2000 по 2013 год.

# %% [markdown]
# ---
#
# ## 4. Категоризация данных
#
# Проведите категоризацию данных:
# - Разделите все игры по оценкам пользователей и выделите такие категории: высокая оценка (от 8 до 10 включительно), средняя оценка (от 3 до 8, не включая правую границу интервала) и низкая оценка (от 0 до 3, не включая правую границу интервала).

# %%
df['category_user_score'] = pd.cut(df_actual['user_score'],
                                   bins = [0, 3, 8, 10],
                                   labels= ['Низкая оценка', 'Средняя оценка', 'Высокая оценка'],
                                   include_lowest=True,  # включает 0 в первый интервал
                                   right=False           # левая граница включена, правая исключена
                                  )

# %% [markdown]
# - Разделите все игры по оценкам критиков и выделите такие категории: высокая оценка (от 80 до 100 включительно), средняя оценка (от 30 до 80, не включая правую границу интервала) и низкая оценка (от 0 до 30, не включая правую границу интервала).

# %%
df['category_critic_score'] = pd.cut(df_actual['critic_score'],
                                     bins = [0, 30, 80, 100],
                                     labels = ['Низнкая оценка', 'Средняя оценка', 'Высокая оценка'],
                                     include_lowest=True,  # включает 0 в первый интервал
                                     right=False           # левая граница включена, правая исключена
                                    )

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Все хорошо, кроме одного. Надо еще ввести категорию для игр, у которых нет оценок. Таких игр может быть достаточно много и важно не терять их.

# %% [markdown]
# - После категоризации данных проверьте результат: сгруппируйте данные по выделенным категориям и посчитайте количество игр в каждой категории.

# %%
user_counts = df.groupby('category_user_score')['name'].count()
print(f' Категории по оценкам пользователей: {user_counts}')
# Out:
#  Категории по оценкам пользователей: category_user_score
# Низкая оценка      116
# Средняя оценка    4081
# Высокая оценка    2286
# Name: name, dtype: int64

# %%
critic_counts = df.groupby('category_critic_score')['name'].count()
print(f' Категории по оценкам критиков: {critic_counts}')
# Out:
#  Категории по оценкам критиков: category_critic_score
# Низнкая оценка    5667
# Средняя оценка    5422
# Высокая оценка    1692
# Name: name, dtype: int64

# %% [markdown]
# - Выделите топ-7 платформ по количеству игр, выпущенных за весь актуальный период.

# %%
top_platform = df_actual.groupby('platform')['name'].count().sort_values(ascending=False).head(7)
print(f'Топ-7 платформ: {top_platform}')
# Out:
# Топ-7 платформ: platform
# PS2     2127
# DS      2120
# Wii     1275
# PSP     1180
# X360    1121
# PS3     1087
# GBA      811
# Name: name, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Рейтинг топ-7 получен

# %% [markdown]
# ---
#
# ## 5. Итоговый вывод
#
# В конце напишите основной вывод и отразите, какую работу проделали. Не забудьте указать описание среза данных и новых полей, которые добавили в исходный датасет.

# %% [markdown]
# В итоге, была проведена предобработка данных с информацией об играх. Был создан датафрейм `df`, его данные были внимательно просмотрены, проанализирована их структура, поля, типы данных. Не подходящие типы данных были изменены позднее, также заполнены пропуски в некоторых полях (`eu_sales` и `jp_sales`), двое строк удалены (с отсутсвующими `name` и `genre`). Дубликаты были устранены и данные были готовы к работе.
#
# После этого была произведена фильтрация для игр, которые вышли с 2000 по 2013 год, был создан новый датафрейм `df_actual`. Следующим шагом я категоризировала данные по двум параметрам. Перед этим создав датафрейм с необходимыми отфильтрованными данными. По этим данным создала два новых поля `category_user_score` и `category_critic_score`, где разделила игры по категориям относительно оценок пользователей и критиков, что позволит выявить самые влиятельные и популярные игры за те годы и дает большое поле для исследования.
#
# Новые столбцы позволили вывести топ-7 платформ по выпущенным играм с 2000 по 2013 год включительно. В числе лидеров мы наблюдаем PS2 (2127), DS (2120) и Wii (1275).

# %% [markdown]
# 1. Срез данных по временному периоду
# Был создан датафрейм `df_actual`, содержащий данные об играх, выпущенных в период с 2000 по 2013 год включительно.
# - **Размер среза:** 12 781 игра
# - **Исходный размер:** 16 956 игр
# - **Отфильтровано:** 4 175 игр (24.6%)
# 2. Добавлены новые поля:
#
#  2.1. `category_user_score`
# Категория оценки пользователей, созданная на основе столбца `user_score`:
# - **Высокая оценка:** от 8 до 10 включительно
# - **Средняя оценка:** от 3 до 8 (не включая 8)
# - **Низкая оценка:** от 0 до 3 (не включая 3)
# - **Тип данных:** категориальный (category)
# - **Количество значений:** 6 483 (остальные - NaN)
#
#  2.2. `category_critic_score`
# Категория оценки критиков, созданная на основе столбца `critic_score`:
# - **Высокая оценка:** от 80 до 100 включительно
# - **Средняя оценка:** от 30 до 80 (не включая 80)
# - **Низкая оценка:** от 0 до 30 (не включая 30)
# - **Тип данных:** категориальный (category)
# - **Количество значений:** 12 781 (все значения заполнены)
#
# 3. Изменения в исходных данных
# - Удалены дубликаты: 241 строка
# - Удалены строки с пропусками в name и genre: 2 строки
# - Заполнены пропуски в eu_sales и jp_sales: средними значениями по группам

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Итоговый Комментарий ревьюера
#
# #### Успех
#
# Благодарю тебя за выполнение работы. Мне понравился твой проект за структурность и последовательность. Во многих местах ты подбираешь оптимальный код и автоматизируешь свою работу, а это очень пригодится в будущем. Выделить бы хотел Предобработку данных. На мой взгляд она получилась особенно удачно. Очень насыщенный итоговый вывод вышел. Старайся такие выводы делать и в будущем.
#
#
# Однако, в проекте есть одно замечание, которые надо исправить:
#
# * Добавить категоризацию игр без оценок.
#
# Еще я оставил рекомендации. Очень надеюсь, что ты учтешь их в этом и последующих проектах.
#
# Жду проект после доработки. Уверен, ты справишься.
# </div>
